# %%
import numpy as np
from scipy.stats import ttest_rel

# %% [markdown]
# ### model results per run

# %% [markdown]
# FL = {
#     "accuracy":    [0.88, 0.89, 0.87, 0.90, 0.89, 0.88, 0.87, 0.89, 0.88, 0.90],
#     "precision":   [0.87, 0.88, 0.86, 0.89, 0.88, 0.87, 0.86, 0.88, 0.87, 0.89],
#     "recall":      [0.86, 0.87, 0.85, 0.88, 0.87, 0.86, 0.85, 0.87, 0.86, 0.88],
#     "f1":          [0.865,0.875,0.855,0.885,0.875,0.865,0.855,0.875,0.865,0.885],
#     "roc_auc":     [0.90, 0.91, 0.89, 0.92, 0.91, 0.90, 0.89, 0.91, 0.90, 0.92]
# }
#
# FLDP = {
#     "accuracy":    [0.85, 0.86, 0.84, 0.87, 0.86, 0.85, 0.84, 0.86, 0.85, 0.87],
#     "precision":   [0.84, 0.85, 0.83, 0.86, 0.85, 0.84, 0.83, 0.85, 0.84, 0.86],
#     "recall":      [0.83, 0.84, 0.82, 0.85, 0.84, 0.83, 0.82, 0.84, 0.83, 0.85],
#     "f1":          [0.835,0.845,0.825,0.855,0.845,0.835,0.825,0.845,0.835,0.855],
#     "roc_auc":     [0.88, 0.89, 0.87, 0.90, 0.89, 0.88, 0.87, 0.89, 0.88, 0.90],
#
#     # ADD YOUR PRIVACY-UTILITY VALUES HERE
#     "privacy_utility": [0.70, 0.72, 0.68, 0.71, 0.72, 0.70, 0.69, 0.71, 0.70, 0.72]
# }
#
# APEM = {
#     "accuracy":    [0.91, 0.92, 0.90, 0.93, 0.92, 0.91, 0.90, 0.92, 0.91, 0.93],
#     "precision":   [0.90, 0.91, 0.89, 0.92, 0.91, 0.90, 0.89, 0.91, 0.90, 0.92],
#     "recall":      [0.89, 0.90, 0.88, 0.91, 0.90, 0.89, 0.88, 0.90, 0.89, 0.91],
#     "f1":          [0.895,0.905,0.885,0.915,0.905,0.895,0.885,0.905,0.895,0.915],
#     "roc_auc":     [0.93, 0.94, 0.92, 0.95, 0.94, 0.93, 0.92, 0.94, 0.93, 0.95],
#
#     # ADD YOUR PRIVACY-UTILITY VALUES HERE
#     "privacy_utility": [0.78, 0.80, 0.77, 0.81, 0.80, 0.79, 0.78, 0.80, 0.79, 0.81]
# }
#
# metrics = ["accuracy", "precision", "recall", "f1", "roc_auc"]
